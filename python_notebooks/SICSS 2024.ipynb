# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer

model = AutoModelForSequenceClassification.from_pretrained("manifesto-project/manifestoberta-xlm-roberta-56policy-topics-sentence-2023-1-1")
tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-large")

sentence = "We will restore funding to the Global Environment Facility and the Intergovernmental Panel on Climate Change, to support critical climate science research around the world"

inputs = tokenizer(sentence,
                   return_tensors="pt",
                   max_length=200,  #we limited the input to 200 tokens during finetuning
                   padding="max_length",
                   truncation=True
                   )

logits = model(**inputs).logits

probabilities = torch.softmax(logits, dim=1).tolist()[0]
probabilities = {model.config.id2label[index]: round(probability * 100, 2) for index, probability in enumerate(probabilities)}
probabilities = dict(sorted(probabilities.items(), key=lambda item: item[1], reverse=True))
print(probabilities)
# {'501 - Environmental Protection: Positive': 67.28, '411 - Technology and Infrastructure': 15.19, '107 - Internationalism: Positive': 13.63, '416 - Anti-Growth Economy: Positive': 2.02...

predicted_class = model.config.id2label[logits.argmax().item()]
print(predicted_class)
# 501 - Environmental Protection: Positive
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/5.59k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# {'501 - Environmental Protection: Positive': 67.28, '411 - Technology and Infrastructure': 15.19, '107 - Internationalism: Positive': 13.63, '416 - Anti-Growth Economy: Positive': 2.02, '506 - Education Expansion': 0.26, '703 - Agriculture and Farmers: Positive': 0.26, '108 - European Community/Union: Positive': 0.21, '101 - Foreign Special Relationships: Positive': 0.16, '410 - Economic Growth: Positive': 0.13, '104 - Military: Positive': 0.06, '402 - Incentives': 0.05, '502 - Culture: Positive': 0.05, '601 - National Way of Life: Positive': 0.05, '201 - Freedom and Human Rights': 0.04, '403 - Market Regulation': 0.04, '407 - Protectionism: Negative': 0.04, '504 - Welfare State Expansion': 0.04, '109 - Internationalism: Negative': 0.03, '301 - Federalism': 0.03, '303 - Governmental and Administrative Efficiency': 0.03, '406 - Protectionism: Positive': 0.03, '408 - Economic Goals': 0.03, '605 - Law and Order: Positive': 0.03, '105 - Military: Negative': 0.02, '106 - Peace': 0.02, '305 - Political Authority': 0.02, '404 - Economic Planning': 0.02, '412 - Controlled Economy': 0.02, '503 - Equality: Positive': 0.02, '602 - National Way of Life: Negative': 0.02, '102 - Foreign Special Relationships: Negative': 0.01, '103 - Anti-Imperialism': 0.01, '110 - European Community/Union: Negative': 0.01, '202 - Democracy': 0.01, '302 - Centralisation': 0.01, '304 - Political Corruption': 0.01, '401 - Free Market Economy': 0.01, '405 - Corporatism/ Mixed Economy': 0.01, '413 - Nationalisation': 0.01, '414 - Economic Orthodoxy': 0.01, '604 - Traditional Morality: Negative': 0.01, '606 - Civic Mindedness: Positive': 0.01, '607 - Multiculturalism: Positive': 0.01, '701 - Labour Groups: Positive': 0.01, '704 - Middle Class and Professional Groups': 0.01, '705 - Underprivileged Minority Groups': 0.01, '706 - Non-economic Demographic Groups': 0.01, '203 - Constitutionalism: Positive': 0.0, '204 - Constitutionalism: Negative': 0.0, '409 - Keynesian Demand Management': 0.0, '415 - Marxist Analysis: Positive': 0.0, '505 - Welfare State Limitation': 0.0, '507 - Education Limitation': 0.0, '603 - Traditional Morality: Positive': 0.0, '608 - Multiculturalism: Negative': 0.0, '702 - Labour Groups: Negative': 0.0}
# 501 - Environmental Protection: Positive

# %%
import os

# List all files in the current directory
files = os.listdir('.')
print(files)
# Out:
# ['.config', 'drive', 'sample_data']

# %%
import os
import pandas as pd

# Define the subfolder
subfolder = 'sample_data'

# Step 1: List all files in the subfolder
files = os.listdir(subfolder)
meta_files = [file for file in files if file.endswith('meta.tsv')]

# Step 2: Initialize an empty list to hold all DataFrames
dfs = []

# Step 3: Read each file into a DataFrame and append to 'dfs'
for file in meta_files:
    file_path = os.path.join(subfolder, file)
    df = pd.read_csv(file_path, sep='\t', index_col=False)  # Assuming files are tab-separated
    dfs.append(df)

# Step 4: Combine all DataFrames into one big DataFrame
combined_df = pd.concat(dfs, ignore_index=True)
df = combined_df

# Now 'df' contains the combined data from all 'meta.tsv' files in the 'sample_data' subfolder

# %%
df
# Out:
#                          Text_ID               ID  \
# 0     ParlaMint-HU-en_2022-06-14    u2022-06-14-0
# 1     ParlaMint-HU-en_2022-06-14    u2022-06-14-1
# 2     ParlaMint-HU-en_2022-06-14    u2022-06-14-2
# 3     ParlaMint-HU-en_2022-06-14    u2022-06-14-3
# 4     ParlaMint-HU-en_2022-06-14    u2022-06-14-4
# ...                          ...              ...
# 7844  ParlaMint-HU-en_2022-11-10  u2022-11-10-236
# 7845  ParlaMint-HU-en_2022-11-10  u2022-11-10-237
# 7846  ParlaMint-HU-en_2022-11-10  u2022-11-10-238
# 7847  ParlaMint-HU-en_2022-11-10  u2022-11-10-239
# 7848  ParlaMint-HU-en_2022-11-10  u2022-11-10-240
#
#                                                   Title        Date  \
# 0     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 1     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 2     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 3     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 4     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# ...                                                 ...         ...
# 7844  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7845  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7846  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7847  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7848  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
#
#                Body       Term Session   Meeting     Sitting Agenda  ...  \
# 0     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 1     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 2     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 3     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 4     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# ...             ...        ...     ...       ...         ...    ...  ...
# 7844  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7845  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7846  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7847  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7848  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
#
#      Speaker_MP Speaker_minister      Speaker_party  \
# 0            MP      notMinister       KNDP-frakció
# 1            MP      notMinister        LMP-frakció
# 2            MP      notMinister       KNDP-frakció
# 3            MP      notMinister     Fidesz-frakció
# 4            MP      notMinister       KNDP-frakció
# ...         ...              ...                ...
# 7844         MP      notMinister         DK-frakció
# 7845      notMP      notMinister             Fidesz
# 7846         MP      notMinister         DK-frakció
# 7847         MP      notMinister  Mi Hazánk-frakció
# 7848         MP      notMinister         DK-frakció
#
#                                      Speaker_party_name Party_status  \
# 0     Parliamentary group of the Christian Democrati...    Coalition
# 1     Parliamentary group of the LMP – Hungary's Gre...   Opposition
# 2     Parliamentary group of the Christian Democrati...    Coalition
# 3     Parliamentary group of the Fidesz – Hungarian ...    Coalition
# 4     Parliamentary group of the Christian Democrati...    Coalition
# ...                                                 ...          ...
# 7844  Parliamentary group of the Democratic Coalitio...   Opposition
# 7845                  Fidesz – Hungarian Civic Alliance            -
# 7846  Parliamentary group of the Democratic Coalitio...   Opposition
# 7847  Parliamentary group of the Our Homeland Moveme...   Opposition
# 7848  Parliamentary group of the Democratic Coalitio...   Opposition
#
#           Party_orientation      Speaker_ID       Speaker_name Speaker_gender  \
# 0                     Right   LatorcaiJanos    Latorcai, János              M
# 1     Centre to centre-left  KanaszNagyMate  Kanász-Nagy, Máté              M
# 2                     Right   LatorcaiJanos    Latorcai, János              M
# 3        Right to far-right     KonczZsofia      Koncz, Zsófia              F
# 4                     Right   LatorcaiJanos    Latorcai, János              M
# ...                     ...             ...                ...            ...
# 7844            Centre-left       OlahLajos        Oláh, Lajos              M
# 7845     Right to far-right     VarghaTamas      Vargha, Tamás              M
# 7846            Centre-left       OlahLajos        Oláh, Lajos              M
# 7847              Far-right       NovakElod        Novák, Előd              M
# 7848            Centre-left       OlahLajos        Oláh, Lajos              M
#
#      Speaker_birth
# 0             1944
# 1             1986
# 2             1944
# 3             1990
# 4             1944
# ...            ...
# 7844          1969
# 7845          1959
# 7846          1969
# 7847          1980
# 7848          1969
#
# [7849 rows x 23 columns]

# %%
import os
import pandas as pd

# Define the subfolder
subfolder = 'sample_data'

# Initialize an empty list to store data
data = []

# Step 1: List all files in the subfolder
files = os.listdir(subfolder)
txt_files = [file for file in files if file.endswith('.txt')]

# Step 2: Iterate over each text file
for file in txt_files:
    file_path = os.path.join(subfolder, file)
    with open(file_path, 'r', encoding='utf-8') as f:
        # Read lines from the text file
        lines = f.read().splitlines()

        # Iterate over each line in the file
        for line in lines:
            # Split each line by tab
            parts = line.split('\t')
            if len(parts) >= 2:
                text_id, text = parts[0], '\t'.join(parts[1:])
                text = text.strip()
                data.append({'text_id': text_id, 'text': text})

# Step 3: Create a DataFrame from the collected data
df_1 = pd.DataFrame(data)

# Now 'df_1' contains the combined data from all '.txt' files in the 'sample_data' subfolder

# %%
# Function to remove content within double square brackets
import re
def remove_bracketed_content(text):
  return re.sub(r'\[\[.*?\]\]', '', text)

# Apply the function to the 'text' column
df_1['text'] = df_1['text'].apply(remove_bracketed_content)

new_data=df.merge(df_1, left_on='ID', right_on='text_id')

new_data = new_data[new_data['Speaker_role'] != 'Chairperson']

# %%
new_data
# Out:
#                          Text_ID               ID  \
# 1     ParlaMint-HU-en_2022-06-14    u2022-06-14-1
# 3     ParlaMint-HU-en_2022-06-14    u2022-06-14-3
# 5     ParlaMint-HU-en_2022-06-14    u2022-06-14-5
# 7     ParlaMint-HU-en_2022-06-14    u2022-06-14-7
# 9     ParlaMint-HU-en_2022-06-14    u2022-06-14-9
# ...                          ...              ...
# 7839  ParlaMint-HU-en_2022-11-10  u2022-11-10-231
# 7841  ParlaMint-HU-en_2022-11-10  u2022-11-10-233
# 7843  ParlaMint-HU-en_2022-11-10  u2022-11-10-235
# 7845  ParlaMint-HU-en_2022-11-10  u2022-11-10-237
# 7847  ParlaMint-HU-en_2022-11-10  u2022-11-10-239
#
#                                                   Title        Date  \
# 1     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 3     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 5     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 7     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 9     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# ...                                                 ...         ...
# 7839  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7841  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7843  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7845  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7847  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
#
#                Body       Term Session   Meeting     Sitting Agenda  ...  \
# 1     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 3     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 5     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 7     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 9     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# ...             ...        ...     ...       ...         ...    ...  ...
# 7839  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7841  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7843  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7845  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7847  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
#
#           Speaker_party                                 Speaker_party_name  \
# 1           LMP-frakció  Parliamentary group of the LMP – Hungary's Gre...
# 3        Fidesz-frakció  Parliamentary group of the Fidesz – Hungarian ...
# 5     Párbeszéd-frakció  Parliamentary group of the Dialogue for Hungar...
# 7        Fidesz-frakció  Parliamentary group of the Fidesz – Hungarian ...
# 9     Mi Hazánk-frakció  Parliamentary group of the Our Homeland Moveme...
# ...                 ...                                                ...
# 7839  Mi Hazánk-frakció  Parliamentary group of the Our Homeland Moveme...
# 7841         DK-frakció  Parliamentary group of the Democratic Coalitio...
# 7843     JOBBIK-frakció  Parliamentary group of the Movement for a Bett...
# 7845             Fidesz                  Fidesz – Hungarian Civic Alliance
# 7847  Mi Hazánk-frakció  Parliamentary group of the Our Homeland Moveme...
#
#      Party_status      Party_orientation      Speaker_ID       Speaker_name  \
# 1      Opposition  Centre to centre-left  KanaszNagyMate  Kanász-Nagy, Máté
# 3       Coalition     Right to far-right     KonczZsofia      Koncz, Zsófia
# 5      Opposition    Centre-left to left     SzaboRebeka      Szabó, Rebeka
# 7       Coalition     Right to far-right    FarkasSandor     Farkas, Sándor
# 9      Opposition              Far-right       NovakElod        Novák, Előd
# ...           ...                    ...             ...                ...
# 7839   Opposition              Far-right       NovakElod        Novák, Előd
# 7841   Opposition            Centre-left      VadaiAgnes       Vadai, Ágnes
# 7843   Opposition           Centre-right       SasZoltan        Sas, Zoltán
# 7845            -     Right to far-right     VarghaTamas      Vargha, Tamás
# 7847   Opposition              Far-right       NovakElod        Novák, Előd
#
#      Speaker_gender Speaker_birth          text_id  \
# 1                 M          1986    u2022-06-14-1
# 3                 F          1990    u2022-06-14-3
# 5                 F          1977    u2022-06-14-5
# 7                 M          1953    u2022-06-14-7
# 9                 M          1980    u2022-06-14-9
# ...             ...           ...              ...
# 7839              M          1980  u2022-11-10-231
# 7841              F          1974  u2022-11-10-233
# 7843              M          1972  u2022-11-10-235
# 7845              M          1959  u2022-11-10-237
# 7847              M          1980  u2022-11-10-239
#
#                                                    text
# 1     Thank you for the floor, Mr President. Dear Ho...
# 3     Thank you very much for the floor. Mr Presiden...
# 5     Thank you very much. Mr President, Ladies and ...
# 7     Thank you very much. Mr President, Ladies and ...
# 9     Thank you for the floor. Dear Parliament, Ther...
# ...                                                 ...
# 7839  Thank you for the floor, Mr President. Mr. Vic...
# 7841  Thank you for the floor, Mr President. Dear Ho...
# 7843  Thank you very much for the floor, Mr Presiden...
# 7845  Thank you very much, Mr. President. Dear Parli...
# 7847  Thank you for the floor. Dear Parliament, I wa...
#
# [3877 rows x 25 columns]

# %%
# Out:
#               text_id                                               text
# 0       u2023-04-12-0  [[The people in this room stand up and greet t...
# 1       u2023-04-12-1  Thank you for the floor. Dear Parliament, Ladi...
# 2       u2023-04-12-2  Thank you very much, Congresswoman Bakos Berna...
# 3       u2023-04-12-3  Thank you very much for the floor. Mr Presiden...
# 4       u2023-04-12-4  Thank you very much, Mrs Zsófia Koncz. Rebeka ...
# ...               ...                                                ...
# 5966  u2023-03-27-288  Thank you very much, Congressman. Judit Ráczné...
# 5967  u2023-03-27-289  Thank you for the floor, Mr President. Dear Ho...
# 5968  u2023-03-27-290  Thank you, Congresswoman. Csaba Nagy, from the...
# 5969  u2023-03-27-291  Thank you for the floor, Mr President. Ladies ...
# 5970  u2023-03-27-292  Thank you, Congressman. Dear Parliament, I hav...
#
# [5971 rows x 2 columns]

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/stesstesste/SICSS_2024/main/hungarian_speeches/2023/ParlaMint-HU-en_2023-02-28-meta.tsv'
df = pd.read_csv(url, delimiter='\t', index_col=False)


import requests

# URL of the raw TSV file on GitHub
file_url = 'https://raw.githubusercontent.com/stesstesste/SICSS_2024/main/hungarian_speeches/2023/ParlaMint-HU-en_2023-02-28.txt'

# Send a GET request to the URL
response = requests.get(file_url)

# Ensure the request was successful
if response.status_code == 200:
    # Split the content by lines
    lines = response.text.splitlines()

    # Initialize an empty list to store data
    data = []

    # Iterate over the lines
    for line in lines:
        # Split each line by tab
        text_id, text = line.split('\t')
        text = text.strip()
        data.append({'text_id': text_id, 'text': text})

    # Print the first few entries to check




df_1 = pd.DataFrame(data)

# %%
# Function to remove content within double square brackets
import re
def remove_bracketed_content(text):
  return re.sub(r'\[\[.*?\]\]', '', text)

# Apply the function to the 'text' column
df_1['text'] = df_1['text'].apply(remove_bracketed_content)

new_data=df.merge(df_1, left_on='ID', right_on='text_id')

new_data = new_data[new_data['Speaker_role'] != 'Chairperson']

# %%
new_data
# Out:
#                         Text_ID               ID  \
# 1    ParlaMint-HU-en_2023-02-28    u2023-02-28-1
# 3    ParlaMint-HU-en_2023-02-28    u2023-02-28-3
# 5    ParlaMint-HU-en_2023-02-28    u2023-02-28-5
# 7    ParlaMint-HU-en_2023-02-28    u2023-02-28-7
# 9    ParlaMint-HU-en_2023-02-28    u2023-02-28-9
# ..                          ...              ...
# 175  ParlaMint-HU-en_2023-02-28  u2023-02-28-175
# 177  ParlaMint-HU-en_2023-02-28  u2023-02-28-177
# 179  ParlaMint-HU-en_2023-02-28  u2023-02-28-179
# 181  ParlaMint-HU-en_2023-02-28  u2023-02-28-181
# 183  ParlaMint-HU-en_2023-02-28  u2023-02-28-183
#
#                                                  Title        Date  \
# 1    Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# 3    Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# 5    Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# 7    Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# 9    Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# ..                                                 ...         ...
# 175  Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# 177  Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# 179  Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# 181  Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
# 183  Hungarian parliamentary corpus ParlaMint-HU, l...  2023-02-28
#
#               Body       Term Session   Meeting     Sitting Agenda  ...  \
# 1    Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# 3    Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# 5    Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# 7    Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# 9    Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# ..             ...        ...     ...       ...         ...    ...  ...
# 175  Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# 177  Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# 179  Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# 181  Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
# 183  Unicameralism  9. ciklus       -  20. ülés  2. ülésnap      -  ...
#
#                                     Speaker_party_name Party_status  \
# 1    Parliamentary group of the LMP – Hungary's Gre...   Opposition
# 3    Parliamentary group of the Fidesz – Hungarian ...    Coalition
# 5    Parliamentary group of the Dialogue for Hungar...   Opposition
# 7    Parliamentary group of the Fidesz – Hungarian ...    Coalition
# 9    Parliamentary group of the Our Homeland Moveme...   Opposition
# ..                                                 ...          ...
# 175  Parliamentary group of the Hungarian Socialist...   Opposition
# 177  Parliamentary group of the Christian Democrati...    Coalition
# 179  Parliamentary group of the Movement for a Bett...   Opposition
# 181  Parliamentary group of the Movement for a Bett...   Opposition
# 183  Parliamentary group of the Our Homeland Moveme...   Opposition
#
#          Party_orientation       Speaker_ID       Speaker_name Speaker_gender  \
# 1    Centre to centre-left   BakosBernadett   Bakos, Bernadett              F
# 3       Right to far-right      KonczZsofia      Koncz, Zsófia              F
# 5      Centre-left to left      MellarTamas      Mellar, Tamás              M
# 7       Right to far-right     DomotorCsaba     Dömötör, Csaba              M
# 9                Far-right  ToroczkaiLaszlo  Toroczkai, László              M
# ..                     ...              ...                ...            ...
# 175            Centre-left       GurmaiZita       Gurmai, Zita              F
# 177                  Right   JuhaszHajnalka   Juhász, Hajnalka              F
# 179           Centre-right     BalassaPeter     Balassa, Péter              M
# 181           Centre-right        SasZoltan        Sas, Zoltán              M
# 183              Far-right        DocsDavid        Dócs, Dávid              M
#
#     Speaker_birth          text_id  \
# 1            1992    u2023-02-28-1
# 3            1990    u2023-02-28-3
# 5            1954    u2023-02-28-5
# 7            1982    u2023-02-28-7
# 9            1978    u2023-02-28-9
# ..            ...              ...
# 175          1965  u2023-02-28-175
# 177          1980  u2023-02-28-177
# 179          1975  u2023-02-28-179
# 181          1972  u2023-02-28-181
# 183          1987  u2023-02-28-183
#
#                                                   text  \
# 1    Thank you for the floor. Dear House, Ladies an...
# 3    Thank you very much for the floor. Dear Parlia...
# 5    Thank you for the floor, Mr President. Dear Ho...
# 7    Thank you for the floor, Mr President. Honoura...
# 9    Thank you for the floor, Mr President. I will ...
# ..                                                 ...
# 175  Thank you very much. If we can continue with t...
# 177  Thank you very much for the word, no one with ...
# 179  Thank you, Mr. President. Dear Secretary of St...
# 181  Thank you very much for the floor, Mr Presiden...
# 183  Mr President, Dear House, The situation of Tra...
#
#                                          probabilities
# 1    {'305 - Political Authority': 25.84, '501 - En...
# 3    {'407 - Protectionism: Negative': 26.24, '410 ...
# 5    {'304 - Political Corruption': 60.8, '202 - De...
# 7    {'303 - Governmental and Administrative Effici...
# 9    {'202 - Democracy': 52.78, '305 - Political Au...
# ..                                                 ...
# 175  {'107 - Internationalism: Positive': 53.99, '3...
# 177  {'107 - Internationalism: Positive': 50.86, '1...
# 179  {'101 - Foreign Special Relationships: Positiv...
# 181  {'104 - Military: Positive': 54.96, '605 - Law...
# 183  {'705 - Underprivileged Minority Groups': 23.3...
#
# [91 rows x 26 columns]

# %%
import dask.dataframe as dd
from dask import delayed

def compute_probabilities(sentence):
  inputs = tokenizer(sentence,
                   return_tensors="pt",
                   max_length=200,  #we limited the input to 200 tokens during finetuning
                   padding="max_length",
                   truncation=True
                   )


  logits = model(**inputs).logits

  probabilities = torch.softmax(logits, dim=1).tolist()[0]
  probabilities = {model.config.id2label[index]: round(probability * 100, 2) for index, probability in enumerate(probabilities)}
  probabilities = dict(sorted(probabilities.items(), key=lambda item: item[1], reverse=True))

  return probabilities

#ask_df = dd.from_pandas(new_data.head(10), npartitions=50)

#dask_df['probabilities'] = dask_df['text'].apply(lambda x: delayed(compute_probabilities)(x), meta=('x', 'object'))

#result = dask_df.compute()

# %%
import multiprocessing

def apply_function_multiprocessing(df, func, num_processes=None):
    if num_processes is None:
        num_processes = multiprocessing.cpu_count() - 1  # Use all available cores except one

    with multiprocessing.Pool(processes=num_processes) as pool:
        results = pool.map(func, df['text'])

    return results

# Apply the function using multiprocessing
results = apply_function_multiprocessing(new_data, compute_probabilities)

# %%
# Out:
# 91

# %%
new_data['probabilities'] = results

# %%
new_data
# Out:
#                          Text_ID               ID  \
# 1     ParlaMint-HU-en_2022-06-14    u2022-06-14-1
# 3     ParlaMint-HU-en_2022-06-14    u2022-06-14-3
# 5     ParlaMint-HU-en_2022-06-14    u2022-06-14-5
# 7     ParlaMint-HU-en_2022-06-14    u2022-06-14-7
# 9     ParlaMint-HU-en_2022-06-14    u2022-06-14-9
# ...                          ...              ...
# 7839  ParlaMint-HU-en_2022-11-10  u2022-11-10-231
# 7841  ParlaMint-HU-en_2022-11-10  u2022-11-10-233
# 7843  ParlaMint-HU-en_2022-11-10  u2022-11-10-235
# 7845  ParlaMint-HU-en_2022-11-10  u2022-11-10-237
# 7847  ParlaMint-HU-en_2022-11-10  u2022-11-10-239
#
#                                                   Title        Date  \
# 1     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 3     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 5     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 7     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# 9     Hungarian parliamentary corpus ParlaMint-HU, l...  2022-06-14
# ...                                                 ...         ...
# 7839  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7841  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7843  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7845  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
# 7847  Hungarian parliamentary corpus ParlaMint-HU, l...  2022-11-10
#
#                Body       Term Session   Meeting     Sitting Agenda  ...  \
# 1     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 3     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 5     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 7     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# 9     Unicameralism  9. ciklus       -   6. ülés  2. ülésnap      -  ...
# ...             ...        ...     ...       ...         ...    ...  ...
# 7839  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7841  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7843  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7845  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
# 7847  Unicameralism  9. ciklus       -  16. ülés  3. ülésnap      -  ...
#
#                                      Speaker_party_name Party_status  \
# 1     Parliamentary group of the LMP – Hungary's Gre...   Opposition
# 3     Parliamentary group of the Fidesz – Hungarian ...    Coalition
# 5     Parliamentary group of the Dialogue for Hungar...   Opposition
# 7     Parliamentary group of the Fidesz – Hungarian ...    Coalition
# 9     Parliamentary group of the Our Homeland Moveme...   Opposition
# ...                                                 ...          ...
# 7839  Parliamentary group of the Our Homeland Moveme...   Opposition
# 7841  Parliamentary group of the Democratic Coalitio...   Opposition
# 7843  Parliamentary group of the Movement for a Bett...   Opposition
# 7845                  Fidesz – Hungarian Civic Alliance            -
# 7847  Parliamentary group of the Our Homeland Moveme...   Opposition
#
#           Party_orientation      Speaker_ID       Speaker_name Speaker_gender  \
# 1     Centre to centre-left  KanaszNagyMate  Kanász-Nagy, Máté              M
# 3        Right to far-right     KonczZsofia      Koncz, Zsófia              F
# 5       Centre-left to left     SzaboRebeka      Szabó, Rebeka              F
# 7        Right to far-right    FarkasSandor     Farkas, Sándor              M
# 9                 Far-right       NovakElod        Novák, Előd              M
# ...                     ...             ...                ...            ...
# 7839              Far-right       NovakElod        Novák, Előd              M
# 7841            Centre-left      VadaiAgnes       Vadai, Ágnes              F
# 7843           Centre-right       SasZoltan        Sas, Zoltán              M
# 7845     Right to far-right     VarghaTamas      Vargha, Tamás              M
# 7847              Far-right       NovakElod        Novák, Előd              M
#
#      Speaker_birth          text_id  \
# 1             1986    u2022-06-14-1
# 3             1990    u2022-06-14-3
# 5             1977    u2022-06-14-5
# 7             1953    u2022-06-14-7
# 9             1980    u2022-06-14-9
# ...            ...              ...
# 7839          1980  u2022-11-10-231
# 7841          1974  u2022-11-10-233
# 7843          1972  u2022-11-10-235
# 7845          1959  u2022-11-10-237
# 7847          1980  u2022-11-10-239
#
#                                                    text  \
# 1     Thank you for the floor, Mr President. Dear Ho...
# 3     Thank you very much for the floor. Mr Presiden...
# 5     Thank you very much. Mr President, Ladies and ...
# 7     Thank you very much. Mr President, Ladies and ...
# 9     Thank you for the floor. Dear Parliament, Ther...
# ...                                                 ...
# 7839  Thank you for the floor, Mr President. Mr. Vic...
# 7841  Thank you for the floor, Mr President. Dear Ho...
# 7843  Thank you very much for the floor, Mr Presiden...
# 7845  Thank you very much, Mr. President. Dear Parli...
# 7847  Thank you for the floor. Dear Parliament, I wa...
#
#                                           probabilities
# 1     {'305 - Political Authority': 61.36, '503 - Eq...
# 3     {'501 - Environmental Protection: Positive': 7...
# 5     {'501 - Environmental Protection: Positive': 7...
# 7     {'501 - Environmental Protection: Positive': 6...
# 9     {'504 - Welfare State Expansion': 61.96, '603 ...
# ...                                                 ...
# 7839  {'105 - Military: Negative': 60.46, '305 - Pol...
# 7841  {'104 - Military: Positive': 51.23, '107 - Int...
# 7843  {'104 - Military: Positive': 81.63, '107 - Int...
# 7845  {'104 - Military: Positive': 59.15, '305 - Pol...
# 7847  {'305 - Political Authority': 24.87, '201 - Fr...
#
# [3877 rows x 26 columns]

# %%
os.listdir()
# Out:
# ['.config', 'drive', '2022_data_probabilities.csv', 'sample_data']

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# Save to Google Drive
file_path = '2022_data_probabilities.csv'
 # Replace with your desired file path
new_data.to_csv(file_path)
print('exported 2022')
# Out:
# exported 2022

# %%
import dask.dataframe as dd
from dask import delayed, compute

import time
new_data_dd = dd.from_pandas(new_data.head(3), npartitions=8)  # Adjust npartitions based on your machine's cores

# Define a delayed function to compute probabilities
@delayed
def compute_probabilities_delayed(text):
    return compute_probabilities(text)

# Apply the function to the Dask DataFrame
prob_delayed = new_data_dd['text'].apply(compute_probabilities_delayed, meta=('text', 'f8'))

start_time = time.time()
# Compute the results
prob = compute(prob_persisted)
end_time = time.time()




# Calculate the elapsed time
elapsed_time = end_time - start_time

print(f"Time taken to run the computation: {elapsed_time:.2f} seconds")

# Flatten the list of results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3cca5375e169> in <cell line: 17>()
#      15 start_time = time.time()
#      16 # Compute the results
# ---> 17 prob = compute(prob_persisted)
#      18 end_time = time.time()
#      19
#
# NameError: name 'prob_persisted' is not defined

# %%
new_data_dd = dd.from_pandas(new_data[:5], npartitions=8)  # Adjust npartitions based on your machine's cores

# Define a delayed function to compute probabilities
@delayed
def compute_probabilities_delayed(text):
    return compute_probabilities(text)
# Use map_partitions for better performance with large DataFrames
prob_delayed = new_data_dd.map_partitions(lambda df: df['text'].apply(compute_probabilities_delayed), meta=('text', 'f8'))

# Persist the intermediate results in memory
prob_persisted = prob_delayed.persist()

start_time = time.time()
# Compute the results
prob = compute(prob_persisted)
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

print(f"Time taken to run the computation: {elapsed_time:.2f} seconds")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-faa0e74bc742> in <cell line: 11>()
#       9
#      10 # Persist the intermediate results in memory
# ---> 11 prob_persisted = prob_delayed.persist()
#      12
#      13 start_time = time.time()
#
# /usr/local/lib/python3.10/dist-packages/dask_expr/_collection.py in persist(self, fuse, **kwargs)
#     445     def persist(self, fuse=True, **kwargs):
#     446         out = self.optimize(fuse=fuse)
# --> 447         return DaskMethodsMixin.persist(out, **kwargs)
#     448
#     449     def compute(self, fuse=True, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/dask/base.py in persist(self, **kwargs)
#     346         dask.persist
#     347         """
# --> 348         (result,) = persist(self, traverse=False, **kwargs)
#     349         return result
#     350
#
# /usr/local/lib/python3.10/dist-packages/dask/base.py in persist(traverse, optimize_graph, scheduler, *args, **kwargs)
#     996
#     997     with shorten_traceback():
# --> 998         results = schedule(dsk, keys, **kwargs)
#     999
#    1000     d = dict(zip(keys, results))
#
# <ipython-input-13-faa0e74bc742> in <lambda>(df)
#       6     return compute_probabilities(text)
#       7 # Use map_partitions for better performance with large DataFrames
# ----> 8 prob_delayed = new_data_dd.map_partitions(lambda df: df['text'].apply(compute_probabilities_delayed), meta=('text', 'f8'))
#       9
#      10 # Persist the intermediate results in memory
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.is_list_like()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.c_is_list_like()
#
# /usr/local/lib/python3.10/dist-packages/dask/delayed.py in __bool__(self)
#     643
#     644     def __bool__(self):
# --> 645         raise TypeError("Truth of Delayed objects is not supported")
#     646
#     647     __nonzero__ = __bool__
#
# TypeError: Truth of Delayed objects is not supported

# %%
import dask.dataframe as dd
from dask_cuda import LocalCUDACluster
from dask.distributed import Client
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import pandas as pd
import time
new_data_dd = dd.from_pandas(new_data, npartitions=8)



# Define a delayed function to compute probabilities
@dd.delayed
def compute_probabilities_delayed(text):
    return compute_probabilities(text)

# Apply the function to the Dask DataFrame
prob_delayed = new_data_dd['text'].apply(compute_probabilities_delayed, meta=('text', 'object'))

# Persist the intermediate results in memory
prob_persisted = prob_delayed.persist()

# Compute the results
start_time = time.time()
prob = prob_persisted.compute()
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time

print(f"Time taken to run the computation: {elapsed_time:.2f} seconds")

# Print the first few results
print(prob)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-a9a2a806add7> in <cell line: 13>()
#      11
#      12 # Define a delayed function to compute probabilities
# ---> 13 @dd.delayed
#      14 def compute_probabilities_delayed(text):
#      15     return compute_probabilities(text)
#
# AttributeError: module 'dask.dataframe' has no attribute 'delayed'

# %%
# Out:
# 260

# %%
sentence=new_data['text'][101]
inputs = tokenizer(sentence,
                   return_tensors="pt",
                   max_length=200,  #we limited the input to 200 tokens during finetuning
                   padding="max_length",
                   truncation=True
                   )

logits = model(**inputs).logits

probabilities = torch.softmax(logits, dim=1).tolist()[0]
probabilities = {model.config.id2label[index]: round(probability * 100, 2) for index, probability in enumerate(probabilities)}
probabilities = dict(sorted(probabilities.items(), key=lambda item: item[1], reverse=True))
#print(probabilities)
# {'501 - Environmental Protection: Positive': 67.28, '411 - Technology and Infrastructure': 15.19, '107 - Internationalism: Positive': 13.63, '416 - Anti-Growth Economy: Positive': 2.02...

predicted_class = model.config.id2label[logits.argmax().item()]
#print(predicted_class)
# 501 - Environmental Protection: Positive
# Out:
# {'301 - Federalism': 73.12, '305 - Political Authority': 6.67, '303 - Governmental and Administrative Efficiency': 5.47, '414 - Economic Orthodoxy': 2.33, '304 - Political Corruption': 2.27, '302 - Centralisation': 1.98, '202 - Democracy': 1.73, '606 - Civic Mindedness: Positive': 1.47, '504 - Welfare State Expansion': 0.96, '204 - Constitutionalism: Negative': 0.81, '503 - Equality: Positive': 0.46, '505 - Welfare State Limitation': 0.32, '203 - Constitutionalism: Positive': 0.23, '408 - Economic Goals': 0.22, '201 - Freedom and Human Rights': 0.19, '404 - Economic Planning': 0.19, '401 - Free Market Economy': 0.1, '601 - National Way of Life: Positive': 0.1, '605 - Law and Order: Positive': 0.1, '502 - Culture: Positive': 0.09, '506 - Education Expansion': 0.08, '402 - Incentives': 0.07, '602 - National Way of Life: Negative': 0.07, '607 - Multiculturalism: Positive': 0.07, '507 - Education Limitation': 0.06, '103 - Anti-Imperialism': 0.05, '110 - European Community/Union: Negative': 0.05, '409 - Keynesian Demand Management': 0.05, '410 - Economic Growth: Positive': 0.05, '704 - Middle Class and Professional Groups': 0.05, '403 - Market Regulation': 0.04, '603 - Traditional Morality: Positive': 0.04, '701 - Labour Groups: Positive': 0.04, '702 - Labour Groups: Negative': 0.04, '105 - Military: Negative': 0.03, '108 - European Community/Union: Positive': 0.03, '405 - Corporatism/ Mixed Economy': 0.03, '411 - Technology and Infrastructure': 0.03, '412 - Controlled Economy': 0.03, '413 - Nationalisation': 0.03, '604 - Traditional Morality: Negative': 0.03, '608 - Multiculturalism: Negative': 0.03, '703 - Agriculture and Farmers: Positive': 0.03, '106 - Peace': 0.02, '107 - Internationalism: Positive': 0.02, '415 - Marxist Analysis: Positive': 0.02, '501 - Environmental Protection: Positive': 0.02, '705 - Underprivileged Minority Groups': 0.02, '101 - Foreign Special Relationships: Positive': 0.01, '102 - Foreign Special Relationships: Negative': 0.01, '104 - Military: Positive': 0.01, '109 - Internationalism: Negative': 0.01, '407 - Protectionism: Negative': 0.01, '416 - Anti-Growth Economy: Positive': 0.01, '706 - Non-economic Demographic Groups': 0.01, '406 - Protectionism: Positive': 0.0}
# 301 - Federalism

# %%
import dask.dataframe as dd
from dask import delayed

def compute_probabilities(sentence):
  inputs = tokenizer(sentence,
                   return_tensors="pt",
                   max_length=200,  #we limited the input to 200 tokens during finetuning
                   padding="max_length",
                   truncation=True
                   )


  logits = model(**inputs).logits

  probabilities = torch.softmax(logits, dim=1).tolist()[0]
  probabilities = {model.config.id2label[index]: round(probability * 100, 2) for index, probability in enumerate(probabilities)}
  probabilities = dict(sorted(probabilities.items(), key=lambda item: item[1], reverse=True))

  return probabilities

dask_df = dd.from_pandas(new_data.head(10), npartitions=3)

dask_df['probabilities'] = dask_df['text'].apply(lambda x: delayed(compute_probabilities)(x), meta=('x', 'object'))

result = dask_df.compute()
